# %% [markdown]
# - Dizionari (solo con metodi essenziali)
# - List Comprehension (sistemare esempio)

# %%
for i in lista:
    if condizione(i):
        modifca(i)

# %%
[modifica(i) for i in lista if condizione(i)]

# %% [markdown]
# - Dizionari
# - List Comprehension
# - lambda functions
# - break per i cicli
# - Funzioni *args, **kwargs (accennati)
# - Classi (cercare di spiegare più il concetto che il codice e lasciare rielaborare)
#
# ---
# Prossime lezioni
#
#
# ## 12/11/2025
# - riprendere classi
# - librerie
# - numpy
# - matplotlib
# - jupyter
#
# (presentazione GANs, Francesca)
# (preparare suddivisione in gruppi)
#
#
# ---
# Reti neurali
# (...)
# (prendere qualcuno che sa dei vari algoritmi di ML, unsupervised, supervised, RL)
#
# (presentazione ai applied to cancer)
# (parlare dei progetti 2-4 persone per gruppo, poster + computer con demo)
# (con il prof, preparare il fondo)
# (l'ultimo giorno potete farci domande e saranno presenti degli eseperti)
#
# ---
# ## 03/12/2025
# (presentazione federate learning)
# (festa dove ognuno porta qualcosa e si presentano i poster. passiamo a "valutare" e rispondere domande)
# (Premio ognuno da il suo voto best poster)
